# %%
# %pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.15.4 does not provide the extra 'srv'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Paste your actual connection URL string below
uri = "mongodb+srv://jayyr2048_db_user:Jayy2048SecurePass@cluster0.zud5y8m.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
"""Basic connection example.
"""

import redis

r = redis.Redis(
    host='smell-mushroom-oranges-10925.db.redis.io',
    port=16023,
    decode_responses=True,
    username="default",
    password="0WheIZFyW48tMnvuXlHoOq8e9jDixl0v",
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %%
from google.cloud import bigquery

# Initialize the client without referencing any JSON path keys.
# Google's libraries will automatically pick up your fresh ADC file!
client = bigquery.Client(project="project-8d552288-1acb-4a23-893f-1acb0217740b")

# Test query to verify your access rights are working perfectly
query_job = client.query("SELECT name FROM `bigquery-public-data.usa_names.usa_1910_current` LIMIT 5")
results = query_job.result()

print("Connection Verified! Outputting query results:")
for row in results:
    print(f" - {row.name}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.cloud import bigquery
#       3 # Initialize the client without referencing any JSON path keys.
#       4 # Google's libraries will automatically pick up your fresh ADC file!
#       5 client = bigquery.Client(project="project-8d552288-1acb-4a23-893f-1acb0217740b")
#
# ImportError: cannot import name 'bigquery' from 'google.cloud' (unknown location)
